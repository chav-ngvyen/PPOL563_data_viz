# %%
import sys, json, requests
import pandas as pd

# Define URL Location of File
url = 'https://raw.githubusercontent.com/data4d/PPOL563/master/EDA/gapminder_dirty_data.json'


# Pull the file and print error code if not successful
pull = requests.get(url)
if pull.status_code!=200:
    print("Error - status code: %s" % pull.status_code)

# Load the data & convert to a pandas dataframe
data = json.loads(pull.content)
data = pd.DataFrame.from_dict(data)

# %%
data.head()
# Out:
#    cluster      country  fertility  life_expect       pop  year  population  \
# 0        0  Afghanistan        7.7       30.332   8891209  1955     8891209
# 1        0  Afghanistan        7.7       31.997   9829450  1960     9829450
# 2        0  Afghanistan        7.7       34.020  10997885  1965    10997885
# 3        0  Afghanistan        7.7       36.088  12430623  1970    12430623
# 4        0  Afghanistan        7.7       38.438  14132019  1975    14132019
#
#    flag  YEAR       P10
# 0     1    55  6.948961
# 1     1    60  6.992529
# 2     1    65  7.041309
# 3     1    70  7.094493
# 4     1    75  7.150204

# %%
data.columns
# Out:
# Index(['cluster', 'country', 'fertility', 'life_expect', 'pop', 'year',
#        'population', 'flag', 'YEAR', 'P10'],
#       dtype='object')

# %%
country = list(data.country.unique())

# %%
for i in country:
    temp = data[data.country == i]
    temp.plot(title = 'population for ' + i, 
              kind = 'scatter', x = 'YEAR', y = 'population')
